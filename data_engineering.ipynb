# %%
# Add dependencies
import pandas as pd

# %%
# Load csv files
p1_file = 'raw_data/CitiBikeTripHistories/JC-201701-citibike-tripdata.csv'
p2_file = 'raw_data/CitiBikeTripHistories/JC-201702-citibike-tripdata.csv'
p3_file = 'raw_data/CitiBikeTripHistories/JC-201703-citibike-tripdata.csv'
p4_file = 'raw_data/CitiBikeTripHistories/JC-201704-citibike-tripdata.csv'
p5_file = 'raw_data/CitiBikeTripHistories/JC-201705-citibike-tripdata.csv'
p6_file = 'raw_data/CitiBikeTripHistories/JC-201706-citibike-tripdata.csv'
p7_file = 'raw_data/CitiBikeTripHistories/JC-201707-citibike-tripdata.csv'
p8_file = 'raw_data/CitiBikeTripHistories/JC-201708-citibike-tripdata.csv'
p9_file = 'raw_data/CitiBikeTripHistories/JC-201709-citibike-tripdata.csv'
p10_file = 'raw_data/CitiBikeTripHistories/JC-201710-citibike-tripdata.csv'
p11_file = 'raw_data/CitiBikeTripHistories/JC-201711-citibike-tripdata.csv'
p12_file = 'raw_data/CitiBikeTripHistories/JC-201712-citibike-tripdata.csv'

q1_file = 'raw_data/CitiBikeDailyRidershipandMembershipData/data-q1-2017.csv'
q2_file = 'raw_data/CitiBikeDailyRidershipandMembershipData/data-q2-2017.csv'
q3_file = 'raw_data/CitiBikeDailyRidershipandMembershipData/data-q3-2017.csv'
q4_file = 'raw_data/CitiBikeDailyRidershipandMembershipData/data-q4-2017.csv'

p1_data = pd.read_csv(p1_file)
p2_data = pd.read_csv(p2_file)
p3_data = pd.read_csv(p3_file)
p4_data = pd.read_csv(p4_file)
p5_data = pd.read_csv(p5_file)
p6_data = pd.read_csv(p6_file)
p7_data = pd.read_csv(p7_file)
p8_data = pd.read_csv(p8_file)
p9_data = pd.read_csv(p9_file)
p10_data = pd.read_csv(p10_file)
p11_data = pd.read_csv(p11_file)
p12_data = pd.read_csv(p12_file)

q1_data = pd.read_csv(q1_file)
q2_data = pd.read_csv(q2_file)
q3_data = pd.read_csv(q3_file)
q4_data = pd.read_csv(q4_file)

# %%
# Merge data sets
data_set1 = [p1_data, p2_data, p3_data, p4_data, p5_data, p6_data, p7_data, p8_data, p9_data, p10_data, p11_data, p12_data]
table1 = pd.concat(data_set1)
table1.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           148  1/1/2017 0:21  1/1/2017 0:24              3276
# 1          1283  1/1/2017 0:24  1/1/2017 0:45              3183
# 2           372  1/1/2017 0:38  1/1/2017 0:44              3183
# 3          1513  1/1/2017 0:38  1/1/2017 1:03              3194
# 4           639  1/1/2017 1:47  1/1/2017 1:58              3183
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id     end station name  end station latitude  \
# 0            3185            City Hall             40.717733
# ...

# %%
table1.count()
# Out:
# tripduration               294928
# starttime                  294928
# stoptime                   294928
# start station id           294928
# start station name         294928
# start station latitude     294928
# start station longitude    294928
# end station id             294928
# end station name           294928
# end station latitude       294928
# end station longitude      294928
# bikeid                     294928
# usertype                   294811
# birth year                 275313
# gender                     294928
# dtype: int64

# %%
# Merge data sets
data_set2 = [q1_data, q2_data, q3_data, q4_data]
table2 = pd.concat(data_set2)
table2.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/17                                              16009
# 1  1/2/17                                               8921
# 2  1/3/17                                              14198
# 3  1/4/17                                              34039
# 4  1/5/17                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
table2.count()
# Out:
# Date                                                  365
# Trips over the past 24-hours (midnight to 11:59pm)    365
# Miles traveled today (midnight to 11:59 pm)           365
# Total Annual Members (All Time)                       365
# 24-Hour Passes Purchased (midnight to 11:59 pm)       365
# 3-Day Passes Purchased (midnight to 11:59 pm)         365
# dtype: int64

# %%
# Export to csv
table1.to_csv("clean_data_2017.csv")
table2.to_csv("clean_quarter_data_2017.csv")
